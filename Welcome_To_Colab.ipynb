# %% [markdown]
# <a href="https://colab.research.google.com/github/sampath-07/Data-Mining-52-/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file_path = "/titanic_clean.csv"

# %%
data=pd.read_csv("/titanic_clean.csv")

# %%
data.describe()
# Out:
#         Unnamed: 0       pclass     survived          age        sibsp  \
# count  1310.000000  1309.000000  1309.000000  1310.000000  1309.000000
# mean    655.500000     2.294882     0.381971    29.881135     0.498854
# std     378.308736     0.837836     0.486055    12.878277     1.041658
# min       1.000000     1.000000     0.000000     0.166700     0.000000
# 25%     328.250000     2.000000     0.000000    22.000000     0.000000
# 50%     655.500000     3.000000     0.000000    29.881135     0.000000
# 75%     982.750000     3.000000     1.000000    35.000000     1.000000
# max    1310.000000     3.000000     1.000000    80.000000     8.000000
#
#              parch         fare        body  has_cabin_number
# count  1309.000000  1308.000000  121.000000       1310.000000
# mean      0.385027    33.295479  160.809917          0.225191
# std       0.865560    51.758668   97.696922          0.417867
# min       0.000000     0.000000    1.000000          0.000000
# ...

# %%
print(data.describe(include=['object']))
# Out:
#                         name   sex    ticket        cabin embarked boat  \
# count                   1309  1309      1309          295     1310  486
# unique                  1307     2       929          186        3   27
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S   13
# freq                       2   843        11            6      917   39
#
#            home.dest
# count            745
# unique           369
# top     New York, NY
# freq              64

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.title("Histogram Example")
plt.xlabel("Value")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data['pclass'].value_counts().plot(kind='bar', color='lightcoral')
plt.title('passenger Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
plt.boxplot(data['age'].dropna(), patch_artist=True, boxprops=dict(facecolor='lightgreen'))
plt.title('Box Plot of age')
plt.ylabel('age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
correlation_matrix = data[['age', 'fare','sibsp', 'parch']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
correlation_matrix = data[['age', 'fare', 'sibsp', 'parch']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd # make sure to import pandas

# Load the dataframe
data = pd.read_csv("/titanic_clean.csv") # corrected line to read the data into a DataFrame

sns.violinplot(x='pclass', y='age', data=data, palette='muted')
plt.title('age distribution by passenger class')
plt.show()
# Out:
# <ipython-input-65-6071dc5af056>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='pclass', y='age', data=data, palette='muted')

# %%
print(data.describe())
# Out:
#         Unnamed: 0       pclass     survived          age        sibsp  \
# count  1310.000000  1309.000000  1309.000000  1310.000000  1309.000000
# mean    655.500000     2.294882     0.381971    29.881135     0.498854
# std     378.308736     0.837836     0.486055    12.878277     1.041658
# min       1.000000     1.000000     0.000000     0.166700     0.000000
# 25%     328.250000     2.000000     0.000000    22.000000     0.000000
# 50%     655.500000     3.000000     0.000000    29.881135     0.000000
# 75%     982.750000     3.000000     1.000000    35.000000     1.000000
# max    1310.000000     3.000000     1.000000    80.000000     8.000000
#
#              parch         fare        body  has_cabin_number
# count  1309.000000  1308.000000  121.000000       1310.000000
# mean      0.385027    33.295479  160.809917          0.225191
# std       0.865560    51.758668   97.696922          0.417867
# min       0.000000     0.000000    1.000000          0.000000
# ...

# %%
print(data.describe(include=['object']))
# Out:
#                         name   sex    ticket        cabin embarked boat  \
# count                   1309  1309      1309          295     1310  486
# unique                  1307     2       929          186        3   27
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S   13
# freq                       2   843        11            6      917   39
#
#            home.dest
# count            745
# unique           369
# top     New York, NY
# freq              64

# %%
plt.hist(data['age'].dropna(), bins=20, edgecolor='black', color='skyblue')
plt.title('age distribution')
plt.xlabel('age')
plt.ylabel('frequency')
plt.show()

# %%
data['pclass'].value_counts().plot(kind='bar', color='lightcoral')
plt.title('passenger Class Distribution')
plt.xlabel('class')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.show()

# %%
plt.boxplot(data['age'].dropna(), patch_artist=True, boxprops=dict(facecolor='lightgreen'))
plt.title('box Plot of age')
plt.ylabel('age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
correlation_matrix = data[['age', 'fare', 'sibsp', 'parch']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True)
plt.title('correlation heatmap')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.violinplot(x='pclass', y='age', data=data, palette='muted')
plt.title('age distribution by passenger class')
plt.show()
# Out:
# <ipython-input-82-e0cd227a7ed3>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='pclass', y='age', data=data, palette='muted')
